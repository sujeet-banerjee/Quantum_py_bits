# %%
file_handle_r = open(
    'C:/Users/Sujeet/Downloads/Sujeet_LR/WhatsApp Image 2026-07-07 at 11.51.56.jpeg',
    'rb+')

file_handle_w = open(
    'C:/Users/Sujeet/Downloads/Sujeet_LR/WhatsApp_Image_python_created.jpeg',
    'wb+')

# %%
print(file_handle_r)
print(file_handle_r.tell())
# bytes = file_handle_r.read()
# print(bytes)
# Out:
# <_io.BufferedRandom name='C:/Users/Sujeet/Downloads/Sujeet_LR/WhatsApp Image 2026-07-07 at 11.51.56.jpeg'>
# 0

# %%
print(file_handle_r.tell())
print(file_handle_r.read(5))
# Out:
# 0
# b'\xff\xd8\xff\xe0\x00'

# %%
# file_handle_r.seek(0)
print(file_handle_r.tell())
# Out:
# 5

# %%
file_handle_r2 = open(
    'C:/Users/Sujeet/Downloads/Sujeet_LR/WhatsApp Image 2026-07-07 at 11.51.56.jpeg',
    'rb+')

print(file_handle_r.tell())
print(file_handle_r2.tell())
# Out:
# 5
# 0

# %%
print(file_handle_r.read(5))
# Out:
# b'\xff\xd8\xff\xe0\x00'

# %%
print(file_handle_r.tell())
# Out:
# 5

# %%
file_handle_r.close()
file_handle_w.close()
file_handle_r2.close()

# %%
with open(
    'C:/Users/Sujeet/Downloads/Sujeet_LR/WhatsApp Image 2026-07-07 at 11.51.56.jpeg',
    'rb+') as file_handle_r:
    print(file_handle_r.tell())
    print(file_handle_r.read(2))

#
print(file_handle_r.read(2))
# Out:
# 0
# b'\xff\xd8'
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[20], line 8
#       5     print(file_handle_r.read(2))
#       7 #
# ----> 8 print(file_handle_r.read(2))
#
# ValueError: read of closed file
