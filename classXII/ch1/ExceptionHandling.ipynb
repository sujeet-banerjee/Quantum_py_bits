# %% [markdown]
# # Ch1 Exceptions
#
# Reference:
#  [https://docs.python.org/3/library/exceptions.html#exception-hierarchy]

# %%
print("We came here!")
raise Exception("You are exceptionally good!")
print('Are you looking good?')

# %%
print("To err is Humane!")
raise Error("We cannot afford this error!")

# %%
print('Hello there!')
raise Warning("A WARN Welcome!")
print('Did you read the last line?')

# %%
import time
try:
    while True:
        time.sleep(1)
except KeyboardInterrupt as ki:
    print("Wow! We stopped the KeyboardInterrupt")
finally:
    print("---- Done! ---------")

# %%
print ("Practicing for try block")
try:
    numerator=50
    denom=int(input("Enter the denominator"))
    quotient=(numerator/denom)
    print(quotient)
    print ("Division performed successfully")
except ZeroDivisionError as ze:
    print ("Denominator as ZERO....")
    raise ValueError(ze)
