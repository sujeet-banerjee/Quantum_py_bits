# %%
usage_records = [
{"user": "Alice", " service ": "S3 Storage ", " cost ": 25.50} ,
{"user": "Bob", " service ": "EC2 Compute ", " cost ": 100.00} ,
{"user": "Alice", " service ": "EC2 Compute ", " cost ": 50.00} ,
{"user": " Charlie ", " service ": "S3 Storage ", " cost ": 12.00} ,
{"user": "Bob", " service ": " Lambda ", " cost ": 5.75} ,
{"user": "Alice", " service ": " Lambda ", " cost ": 15.00} ,
{"user": " Charlie ", " service ": "EC2 Compute ", " cost ": 80.00} ,
{"user": "Alice", " service ": "S3 Storage ", " cost ": 10.25}
]

print(usage_records)
# Out:
# [{'user': 'Alice', ' service ': 'S3 Storage ', ' cost ': 25.5}, {'user': 'Bob', ' service ': 'EC2 Compute ', ' cost ': 100.0}, {'user': 'Alice', ' service ': 'EC2 Compute ', ' cost ': 50.0}, {'user': ' Charlie ', ' service ': 'S3 Storage ', ' cost ': 12.0}, {'user': 'Bob', ' service ': ' Lambda ', ' cost ': 5.75}, {'user': 'Alice', ' service ': ' Lambda ', ' cost ': 15.0}, {'user': ' Charlie ', ' service ': 'EC2 Compute ', ' cost ': 80.0}, {'user': 'Alice', ' service ': 'S3 Storage ', ' cost ': 10.25}]

# %%
# Names:
uniq_names = {""}
for indx in range(0, len(usage_records)):
    print(usage_records[indx]["user"])
    uniq_names.add(usage_records[indx]["user"])
print(uniq_names)
# Out:
# Alice
# Bob
# Alice
#  Charlie
# Bob
# Alice
#  Charlie
# Alice
# {'', ' Charlie ', 'Bob', 'Alice'}

# %%
print([1,2,3] + [3, 5, 4, 2])
print({3, 5, 4, 2} | {1,2,3})
{'figure':100, 'word':'Hundred',
'figure':10, 'word':'Ten', 'figure':1000, 'word':'Thousand'} | { 'a': 1,
'b':2}

print(True | False | True | True)
print(True & False & True & True)
print(True + False + True + True)
print(True * False * True * True)
print(True ^ True)
print(True ^ False)
print(True - False - True - True)
# Out:
# [1, 2, 3, 3, 5, 4, 2]
# {1, 2, 3, 4, 5}
# True
# False
# 3
# 0
# False
# True
# -2
