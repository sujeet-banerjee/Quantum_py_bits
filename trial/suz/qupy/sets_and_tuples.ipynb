# %%
# list variable creation
my_list = []
print(my_list)
# Empty list is printed as []
# Out:
# []

# %%
my_list.append(1)
print(my_list)
# Out:
# [1]

# %%
my_list.append("Alex")
print(my_list)
# Out:
# [1, 'Alex']

# %%
my_list.append("Stsss")

# %%
print(my_list)
print("How many students? count = ", len(my_list))
# Out:
# [1, 'Alex', 'Stsss', True, [1, 2, 3], 1, 'Alex']
# How many students? count =  7

# %%
my_list.append(True)

# %%
another_list = [1, 2, 3]
my_list.append(another_list)

# %%
my_list.append(1)
my_list.append("Alex")

# %%
# Fetch element by its index
print(my_list[4])
print(my_list[-1])
print(my_list[7])
# Out:
# [1, 2, 3]
# Alex
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[22], line 3
#       1 print(my_list[4])
#       2 print(my_list[-1])
# ----> 3 print(my_list[7])
#
# IndexError: list index out of range

# %%
# Sets

#empty set {}
my_set = {1, 2, 3, 3, 5, 2}
print(my_set)
print(type(my_set))
# Out:
# {1, 2, 3, 5}
# <class 'set'>

# %%
my_set.add("Alex")
print(my_set)
# Out:
# {1, 2, 3, 4, 5, 'Stsss', 'Alex'}

# %%
my_set.add(4)
my_set.add("Alex")
my_set.add("Stsss")

# %%
# Tuples
# storing (x, y) coordinates
# Google maps (longitude, lattitude)
my_tuple = (1, "Alex")
print(my_tuple)

# 3D typle (longi, lattitude, altitude)
coordinates = (1, 2, 3)
print(coordinates)
# Out:
# (1, 'Alex')
# (1, 2, 3)

# %%
# Store (x1, y1), (x2, y2)
list_of_graph_points:[] = [
    (1, 8),
    (2, 10),
    (3, 12),
    (4, 14),
    (5, 16),
    (1, 8),
]
print(list_of_graph_points)
print(len(list_of_graph_points))
print(list_of_graph_points[4][0])
# Out:
# [(1, 8), (2, 10), (3, 12), (4, 14), (5, 16), (1, 8)]
# 6
# 5

# %%
# Store (x1, y1), (x2, y2)
set_of_graph_points = {
    (1, 8),
    (2, 10),
    (3, 12),
    (4, 14),
    (5, 16),
    (1, 8),
}
print(set_of_graph_points)
print(len(set_of_graph_points))
# Out:
# {(5, 16), (4, 14), (3, 12), (2, 10), (1, 8)}
# 5
