# %%
from trial.suz.qupy.sets_and_tuples import another_list

mlist = [1, 2, 3]
#print(type(mlist))
print(mlist)
print(mlist[1])
print(mlist[-1])
# Out:
# <class 'list'>
# [1, 2, 3]
# 2
# 3

# %%
mlist.append(100)
# print(mlist)
# print(mlist[1])
# print(mlist[-1])

# %%
mlist.remove(3)

print(mlist)
print(mlist[1])
print(mlist[-1])
# Out:
# [1, 2, 100, 100]
# 2
# 100

# %%
mlist.remove(1)
mlist.remove(2)
print(mlist)
# Out:
# [100, 100]

# %%
mlist = [2,3,4,5,12,3,4,3,44,5,6,7,777,8,8,9]
print("Whole list: ", mlist)
print("Part list: ", mlist[0:4])
print("Part list: ", mlist[4:5])
# Out:
# Whole list:  [2, 3, 4, 5, 12, 3, 4, 3, 44, 5, 6, 7, 777, 8, 8, 9]
# Part list:  [2, 3, 4, 5]
# Part list:  [12]

# %%
print("Whole list: ", mlist)

# print(mlist[0]*100)
# print(mlist[1]*100)
# print(mlist[2]*100)
# print(mlist[3]*100)
# print(mlist[4]*100)
# print(mlist[5]*100)
# print(mlist[6]*100)

another_list = []
# another_list.append(mlist[0])
# another_list.append(mlist[1])
# another_list.append(mlist[2])
# another_list.append(mlist[3])

for elm in mlist:
    # do something
    # print(elm * 100)
    # print("Hi!")
    another_list.append(elm)

print("Another list: ", another_list)
# Out:
# Whole list:  [2, 3, 4, 5, 12, 3, 4, 3, 44, 5, 6, 7, 777, 8, 8, 9]
# Another list:  [2, 3, 4, 5, 12, 3, 4, 3, 44, 5, 6, 7, 777, 8, 8, 9]

# %%
sum = 0

for elm in mlist:
    sum = sum + elm
    print("New Sum: ", sum)

print(sum)
# Out:
# New Sum:  2
# New Sum:  5
# New Sum:  9
# New Sum:  14
# New Sum:  26
# New Sum:  29
# New Sum:  33
# New Sum:  36
# New Sum:  80
# New Sum:  85
# New Sum:  91
# New Sum:  98
# New Sum:  875
# New Sum:  883
# New Sum:  891
# New Sum:  900
# 900
